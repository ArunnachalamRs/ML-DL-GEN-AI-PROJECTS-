# %%
import pandas as pd

data = [
    [22, 30000, 40, 2, 620],
    [25, 35000, 45, 3, 640],
    [30, 50000, 60, 5, 680],
    [35, 65000, 70, 6, 700],
    [40, 80000, 80, 7, 720],
    [28, 42000, 55, 4, 660],
    [45, 90000, 85, 8, 740],
    [50, 110000, 90, 9, 760],
    [33, 58000, 65, 5, 690],
    [38, 72000, 75, 6, 710],
    [27, 40000, 50, 4, 650],
    [42, 85000, 82, 7, 730],
]

columns = [
    "Age",
    "AnnualIncome",
    "SpendingScore",
    "VisitsPerMonth",
    "CreditScore"
]

df = pd.DataFrame(data, columns=columns)
df.to_csv("customer_data.csv", index=False)

print("Dataset created successfully: customer_data.csv")
print(df.head())
# Out:
# Dataset created successfully: customer_data.csv
#    Age  AnnualIncome  SpendingScore  VisitsPerMonth  CreditScore
# 0   22         30000             40               2          620
# 1   25         35000             45               3          640
# 2   30         50000             60               5          680
# 3   35         65000             70               6          700
# 4   40         80000             80               7          720

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("customer_data.csv")
df.head(5)
# Out:
#    Age  AnnualIncome  SpendingScore  VisitsPerMonth  CreditScore
# 0   22         30000             40               2          620
# 1   25         35000             45               3          640
# 2   30         50000             60               5          680
# 3   35         65000             70               6          700
# 4   40         80000             80               7          720

# %%
scaler=StandardScaler()
x_sca=scaler.fit_transform(df)

# %%
model= PCA(n_components=2)
x_pca=model.fit(x_sca)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# Apply PCA (reduce to 2 dimensions)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create PCA DataFrame
pca_df = pd.DataFrame(
    X_pca,
    columns=["PrincipalComponent1", "PrincipalComponent2"]
)

print("\nReduced Data (2D):")
print(pca_df.head())

# Explained variance
print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)

print("\nTotal Variance Retained:",
      sum(pca.explained_variance_ratio_))
# Out:
# Reduced Data (2D):
#    PrincipalComponent1  PrincipalComponent2
# 0            -3.616351             0.283938
# 1            -2.775720             0.138952
# 2            -0.914294            -0.227868
# 3             0.362970            -0.163633
# 4             1.640234            -0.099397
#
# Explained Variance Ratio:
# [0.99025531 0.00565054]
#
# Total Variance Retained: 0.9959058502504234
